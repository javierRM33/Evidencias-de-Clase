# %% [markdown]
# <a href="https://colab.research.google.com/github/javierRM33/Evidencias-de-Clase/blob/main/Activity_5_Data_interpretations_using_Histograms_%26_Boxplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Path = '/content/drive/MyDrive/minería de datos/antropometria-dataset-1.csv'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import plotly
import plotly.express as px

# %%
df = pd.read_csv(Path)
df
# Out:
#         folio  intp  entidad                         desc_ent  sexo  edad  \
# 0      210295     2       21                           PUEBLA     2    38
# 1      101655     3       10                          DURANGO     2    11
# 2       10287     6        1                   AGUASCALIENTES     2    18
# 3       91526     4        9                 DISTRITO FEDERAL     1    10
# 4      210939     3       21                           PUEBLA     2    19
# ...       ...   ...      ...                              ...   ...   ...
# 18635  300116     2       30  VERACRUZ DE IGNACIO DE LA LLAVE     2    73
# 18636   40253     1        4                         CAMPECHE     2    75
# 18637  301099     1       30  VERACRUZ DE IGNACIO DE LA LLAVE     1    86
# 18638  250801     1       25                          SINALOA     2    72
# 18639   11786     2        1                   AGUASCALIENTES     2    71
#
#        meses   peso  ropa   talla  ... hpresion tbrazo  htension  PrimaryLast  \
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
sns.boxplot(data=df.loc[:,
                        ['talla']
                        ]);

# %%
sns.histplot(data=df.loc[:, ['talla']], kde=False)
plt.xlabel('Talla')
plt.ylabel('Frecuencia')
plt.title('Histograma de Talla')
plt.show()

# %%
sns.histplot(data=df.loc[:, ['peso']], kde=False)
plt.xlabel('peso')
plt.ylabel('Frecuencia')
plt.title('Histograma de Talla')
plt.show()

# %%
sns.boxplot(data=df.loc[:,
                        ['peso']
                        ]);

# %%
sns.boxplot(data=df.loc[:,
                        ['cintura']
                        ]);

# %%
sns.boxplot(x=df['cintura'], orient='v')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.boxplot(x=df['edad'], orient='v')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.boxplot(x=df['edad'], orient='v')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
# Calcular la mediana
medianapeso = df["peso"].median()

# Graficar el boxplot
sns.boxplot(df["peso"], showfliers=False)
plt.xlim(50, 80)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (50.0, 80.0)

# %%
AGUAS = df['peso'][df["desc_ent"] == 'AGUASCALIENTES']
BC = df['peso'][df["desc_ent"] == 'BAJA CALIFORNIA']
BCS = df['peso'][df["desc_ent"] == 'BAJA CALIFORNIA SUR']
df_filtered = np.concatenate((AGUAS,BC,BCS)) 
sns.boxplot(df_filtered, showfliers=False)

plt.xlim(50, 90)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (50.0, 90.0)

# %%
sns.boxplot(data=df[df['sexo'] == 2][['peso']], color='b',)
plt.ylabel('Peso')
plt.title('Boxplot del peso en sexo 2')
plt.show()

# %%
sns.boxplot(y=df[df['sexo'] == 2]['peso'], color='b')
plt.ylabel('Peso')
plt.title('Boxplot del peso en sexo 2')
plt.show()

# %%
edad_sexo2 = df[df['sexo'] == 2]['edad']
sns.boxplot(edad_sexo2, color='b')
plt.xlabel('Edad')
plt.title('Boxplot de la edad en sexo 2')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.plot(np.arange(0,30),df_filtered[0:30])
plt.show()

# %%
plt.plot(np.arange(0,30),df['peso'][0:30])
plt.show()

# %%
pd.pivot_table(df,
               index = 'desc_ent',
               values= ['peso'],
               columns= 'sexo',
               aggfunc='median')
# Out:
#                                     peso
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000
# BAJA CALIFORNIA                  70.6500  64.2000
# BAJA CALIFORNIA SUR              76.6500  68.5500
# CAMPECHE                         67.3500  62.3750
# CHIAPAS                          59.2000  56.0250
# CHIHUAHUA                        69.3000  64.6250
# COAHUILA DE ZARAGOZA             68.3000  67.3000
# COLIMA                           71.7000  66.0000
# DISTRITO FEDERAL                 69.0000  61.4500
# DURANGO                          70.3500  62.5000
# GUANAJUATO                       65.0625  60.3250
# GUERRERO                         60.5000  57.2000
# HIDALGO                          63.3000  57.9000
# JALISCO                          65.5875  63.3500
# MEXICO                           62.4500  56.9500
# MICHOACAN DE OCAMPO              67.6250  63.4000
# MORELOS                          65.2000  61.4500
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
tablecadera = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['cadera'],
               columns= 'sexo',
               aggfunc='median')

tablecadera
# Out:
#                                   cadera
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                    95.650  100.000
# BAJA CALIFORNIA                   97.600  100.500
# BAJA CALIFORNIA SUR              100.300  101.800
# CAMPECHE                          96.900   99.975
# CHIAPAS                           91.000   94.550
# CHIHUAHUA                         97.400  100.600
# COAHUILA DE ZARAGOZA              96.400  102.400
# COLIMA                            98.050  102.600
# DISTRITO FEDERAL                  96.525   99.900
# DURANGO                           96.700   98.500
# GUANAJUATO                        93.875   98.000
# GUERRERO                          91.425   96.550
# HIDALGO                           93.000   96.100
# JALISCO                           94.575  101.050
# MEXICO                            93.500   96.475
# MICHOACAN DE OCAMPO               94.450   99.150
# MORELOS                           93.750   98.800
# ...

# %%
table = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['peso'],
               columns= 'sexo',
               aggfunc='median')

plt.plot(table.index, table[('peso', 1)], color='blue', label='Sexo 1')
plt.plot(table.index, table[('peso', 2)], color='red', label='Sexo 2')
plt.xlabel('desc_ent')
plt.ylabel('Mediana de peso')
plt.title('Gráfica de Line Plots de peso por entidad')
plt.legend()
plt.show()

# %%
table = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['cadera'],
               columns= 'sexo',
               aggfunc='median')

plt.plot(table.index, table[('cadera', 1)], color='blue', label='Sexo 1')
plt.plot(table.index, table[('cadera', 2)], color='red', label='Sexo 2')
plt.xlabel('desc_ent')
plt.ylabel('Mediana de cadera')
plt.title('Gráfica de Line Plots de peso por entidad')
plt.legend()
plt.show()

# %%
table = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['cintura'],
               columns= 'sexo',
               aggfunc='median')


plt.plot(table.index, table[('cintura', 2)], color='red', label='Sexo 2')
plt.xlabel('desc_ent')
plt.ylabel('Mediana de cintura')
plt.title('Gráfica de Line Plots de peso por entidad')
plt.legend()
plt.show()

# %%
table = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['cintura'],
               columns= 'sexo',
               aggfunc='median')


plt.plot(table.index, table[('cintura', 1)], color='red', label='Sexo 2')
plt.xlabel('desc_ent')
plt.ylabel('Mediana de cintura')
plt.title('Gráfica de Line Plots de peso por entidad')
plt.legend()
plt.show()

# %%
table = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['peso'],
               columns= 'sexo',
               aggfunc='median')

table
# Out:
#                                     peso
# sexo                                   1        2
# desc_ent
# AGUASCALIENTES                   69.9500  63.7000
# BAJA CALIFORNIA                  70.6500  64.2000
# BAJA CALIFORNIA SUR              76.6500  68.5500
# CAMPECHE                         67.3500  62.3750
# CHIAPAS                          59.2000  56.0250
# CHIHUAHUA                        69.3000  64.6250
# COAHUILA DE ZARAGOZA             68.3000  67.3000
# COLIMA                           71.7000  66.0000
# DISTRITO FEDERAL                 69.0000  61.4500
# DURANGO                          70.3500  62.5000
# GUANAJUATO                       65.0625  60.3250
# GUERRERO                         60.5000  57.2000
# HIDALGO                          63.3000  57.9000
# JALISCO                          65.5875  63.3500
# MEXICO                           62.4500  56.9500
# MICHOACAN DE OCAMPO              67.6250  63.4000
# MORELOS                          65.2000  61.4500
# ...

# %%
ser=pd.pivot_table(df,
               index = ['desc_ent'],
               values= 'peso',
               aggfunc='median')
ser
# Out:
#                                     peso
# desc_ent
# AGUASCALIENTES                   66.6000
# BAJA CALIFORNIA                  67.9500
# BAJA CALIFORNIA SUR              71.2500
# CAMPECHE                         64.3500
# CHIAPAS                          57.2000
# CHIHUAHUA                        66.3000
# COAHUILA DE ZARAGOZA             67.7000
# COLIMA                           68.9000
# DISTRITO FEDERAL                 64.0250
# DURANGO                          65.7000
# GUANAJUATO                       62.0625
# GUERRERO                         57.9500
# HIDALGO                          59.7000
# JALISCO                          64.2000
# MEXICO                           59.5500
# MICHOACAN DE OCAMPO              65.8000
# MORELOS                          62.5750
# NAYARIT                          66.6250
# NUEVO LEON                       66.7000
# OAXACA                           57.6000
# PUEBLA                           60.3500
# QUERETARO                        62.4000
# ...

# %%
ser2 = ser['peso'].values
ser2
# Out:
# array([66.6   , 67.95  , 71.25  , 64.35  , 57.2   , 66.3   , 67.7   ,
#        68.9   , 64.025 , 65.7   , 62.0625, 57.95  , 59.7   , 64.2   ,
#        59.55  , 65.8   , 62.575 , 66.625 , 66.7   , 57.6   , 60.35  ,
#        62.4   , 63.275 , 60.1   , 67.15  , 68.55  , 65.65  , 67.5   ,
#        62.025 , 61.1   , 62.15  , 63.75  ])

# %%
plt.plot(ser2)

plt.show()

# %%
edadx = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['edad'],
               columns= 'sexo',
               aggfunc='sum')

edadx
# Out:
#                                   edad
# sexo                                 1      2
# desc_ent
# AGUASCALIENTES                    9610  11268
# BAJA CALIFORNIA                   8268   9783
# BAJA CALIFORNIA SUR               8586   8339
# CAMPECHE                          8548   9857
# CHIAPAS                           8011  11345
# CHIHUAHUA                         9348  11685
# COAHUILA DE ZARAGOZA              9766  10577
# COLIMA                            9272  12024
# DISTRITO FEDERAL                  5983   7009
# DURANGO                           8812  11971
# GUANAJUATO                        9038  13280
# GUERRERO                          8690  14430
# HIDALGO                           6169  12076
# JALISCO                           7511  11430
# MEXICO                            5394   8562
# MICHOACAN DE OCAMPO               9159  12336
# MORELOS                           7234  12672
# NAYARIT                           8031  11945
# ...

# %%
sns.boxplot(x=df['edad'], orient='v')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
serx=pd.pivot_table(df,
               index = ['desc_ent'],
               values= 'peso',
               aggfunc='sum')
serx
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   43464.350
# BAJA CALIFORNIA                  38615.540
# BAJA CALIFORNIA SUR              38058.875
# CAMPECHE                         35391.395
# CHIAPAS                          35029.175
# CHIHUAHUA                        39127.075
# COAHUILA DE ZARAGOZA             41710.335
# COLIMA                           41177.445
# DISTRITO FEDERAL                 25526.755
# DURANGO                          38485.855
# GUANAJUATO                       42325.890
# GUERRERO                         38396.110
# HIDALGO                          31077.885
# JALISCO                          35549.645
# MEXICO                           27488.425
# MICHOACAN DE OCAMPO              38875.100
# MORELOS                          35328.960
# NAYARIT                          36598.005
# NUEVO LEON                       43571.425
# OAXACA                           35280.040
# ...

# %%
serxx = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['peso'],
               columns= 'sexo',
               aggfunc='sum')

serxx
# Out:
#                                       peso
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   21135.585  22328.765
# BAJA CALIFORNIA                  18847.440  19768.100
# BAJA CALIFORNIA SUR              19721.425  18337.450
# CAMPECHE                         16263.565  19127.830
# CHIAPAS                          14474.575  20554.600
# CHIHUAHUA                        18256.550  20870.525
# COAHUILA DE ZARAGOZA             20593.055  21117.280
# COLIMA                           18672.705  22504.740
# DISTRITO FEDERAL                 12086.155  13440.600
# DURANGO                          17555.845  20930.010
# GUANAJUATO                       18852.320  23473.570
# GUERRERO                         16779.865  21616.245
# HIDALGO                          11793.860  19284.025
# JALISCO                          15159.285  20390.360
# MEXICO                           12059.800  15428.625
# ...

# %%
df_sexo2 = df[df['sexo'] == 2]

# %%
serxx_sexo2 = pd.pivot_table(df_sexo2,
               index = 'desc_ent',
               values= 'peso',
               aggfunc='sum')
serxx_sexo2
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   22328.765
# BAJA CALIFORNIA                  19768.100
# BAJA CALIFORNIA SUR              18337.450
# CAMPECHE                         19127.830
# CHIAPAS                          20554.600
# CHIHUAHUA                        20870.525
# COAHUILA DE ZARAGOZA             21117.280
# COLIMA                           22504.740
# DISTRITO FEDERAL                 13440.600
# DURANGO                          20930.010
# GUANAJUATO                       23473.570
# GUERRERO                         21616.245
# HIDALGO                          19284.025
# JALISCO                          20390.360
# MEXICO                           15428.625
# MICHOACAN DE OCAMPO              21750.450
# MORELOS                          21457.410
# NAYARIT                          20700.090
# NUEVO LEON                       23012.170
# OAXACA                           20624.750
# ...

# %%
serxx_sexo2 = serxx
serxx_sexo2.plot.bar(color='b')
plt.xlabel('desc_ent')
plt.ylabel('Suma de peso')
plt.title('Gráfica de bar plots de sexo 2')
plt.show()

# %%
serxx_sexo2 = serxx.loc[:, ('peso', 2)].nlargest(10)
serxx_sexo2.plot.barh(color='b')
plt.xlabel('Suma de peso')
plt.ylabel('desc_ent')
plt.title('Gráfica de bar plots de los 10 estados con mayor suma de peso en sexo 2')
plt.show()

# %%
sistolx = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['sistol'],
               columns= 'sexo',
               aggfunc='sum')

sistolx
# Out:
#                                    sistol
# sexo                                    1         2
# desc_ent
# AGUASCALIENTES                   37608.00  42565.25
# BAJA CALIFORNIA                  32240.00  35515.50
# BAJA CALIFORNIA SUR              32076.00  31207.00
# CAMPECHE                         28854.50  35136.25
# CHIAPAS                          28550.00  40385.50
# CHIHUAHUA                        32073.75  37742.75
# COAHUILA DE ZARAGOZA             36171.25  36969.25
# COLIMA                           30854.75  38381.25
# DISTRITO FEDERAL                 20036.00  24548.25
# DURANGO                          31436.75  39155.50
# GUANAJUATO                       34864.00  44234.50
# GUERRERO                         31312.00  43056.75
# HIDALGO                          22626.00  38481.25
# JALISCO                          26649.25  36332.25
# MEXICO                           21846.75  29587.00
# MICHOACAN DE OCAMPO              31250.25  40552.75
# ...

# %%
serxx_sexo2 = sistolx.loc[:, ('sistol', 2)].nlargest(10)
serxx_sexo2.plot.barh(color='b')
plt.xlabel('Suma de peso')
plt.ylabel('desc_ent')
plt.title('Gráfica de bar plots de los 10 estados con mayor suma de peso en sexo 2')
plt.show()

# %%
ropax = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['ropa'],
               columns= 'sexo',
               aggfunc='sum')

ropax
# Out:
#                                 ropa
# sexo                               1    2
# desc_ent
# AGUASCALIENTES                   493  579
# BAJA CALIFORNIA                  402  466
# BAJA CALIFORNIA SUR              415  440
# CAMPECHE                         350  443
# CHIAPAS                          378  540
# CHIHUAHUA                        415  526
# COAHUILA DE ZARAGOZA             417  439
# COLIMA                           410  543
# DISTRITO FEDERAL                 247  298
# DURANGO                          425  515
# GUANAJUATO                       467  590
# GUERRERO                         431  570
# HIDALGO                          311  518
# JALISCO                          352  479
# MEXICO                           269  370
# MICHOACAN DE OCAMPO              408  543
# MORELOS                          361  554
# NAYARIT                          400  542
# NUEVO LEON                       427  530
# OAXACA                           372  551
# ...

# %%
s2 = ropax.loc[:, ('ropa', 1)].nlargest(10)
s2.plot.barh(color='b')
plt.xlabel('Suma de peso')
plt.ylabel('desc_ent')
plt.title('Gráfica de bar plots de los 10 estados con mayor suma de peso en sexo 2')
plt.show()

# %%
edadx2 = pd.pivot_table(df,
               index = 'desc_ent',
               values= ['edad'],
               columns= 'sexo',
               aggfunc='median')

edadx2
# Out:
#                                  edad
# sexo                                1     2
# desc_ent
# AGUASCALIENTES                   28.5  28.0
# BAJA CALIFORNIA                  25.0  29.5
# BAJA CALIFORNIA SUR              29.0  29.0
# CAMPECHE                         33.0  30.0
# CHIAPAS                          24.0  28.0
# CHIHUAHUA                        32.0  34.0
# COAHUILA DE ZARAGOZA             26.0  33.0
# COLIMA                           30.0  34.0
# DISTRITO FEDERAL                 26.0  26.0
# DURANGO                          30.0  35.0
# GUANAJUATO                       22.0  34.0
# GUERRERO                         27.0  37.0
# HIDALGO                          26.0  35.0
# JALISCO                          30.5  36.0
# MEXICO                           20.0  28.0
# MICHOACAN DE OCAMPO              31.0  32.0
# MORELOS                          29.0  35.0
# NAYARIT                          30.0  35.0
# NUEVO LEON                       30.0  34.0
# ...

# %%
s2l = edadx2.loc[:, ('edad', 1)].nlargest(10)
s2l.plot.barh(color='b')
plt.xlabel('Suma de peso')
plt.ylabel('desc_ent')
plt.title('Gráfica de bar plots de los 10 estados con mayor suma de peso en sexo 2')
plt.show()

# %%
sns.boxplot(s2l, color='b')
plt.xlabel('Suma de peso')
plt.title('Boxplot de la suma de peso en sexo 2')

plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['desc_ent']
# Out:
# 0                                 PUEBLA
# 1                                DURANGO
# 2                         AGUASCALIENTES
# 3                       DISTRITO FEDERAL
# 4                                 PUEBLA
#                       ...
# 18635    VERACRUZ DE IGNACIO DE LA LLAVE
# 18636                           CAMPECHE
# 18637    VERACRUZ DE IGNACIO DE LA LLAVE
# 18638                            SINALOA
# 18639                     AGUASCALIENTES
# Name: desc_ent, Length: 18640, dtype: object

# %%
sns.boxplot(data=df.loc[:,
                        ['talla']
                        ]);

# %%
medianpeso = df["peso"].median()
medianpeso
# Out:
# 63.7

# %%
sns.boxplot(data=df.loc[:,
                        ['talla']
                        ]);

# %%
ag = df.groupby(['sexo','peso',]).size()
ag = ag.to_frame()
ag
# Out:
#               0
# sexo peso
# 1    20.550   1
#      22.750   1
#      22.825   1
#      23.000   1
#      23.075   1
# ...          ..
# 2    151.550  1
#      154.100  1
#      161.450  1
#      165.000  1
#      168.600  1
#
# [4207 rows x 1 columns]

# %%
def custom_cs(x):
  if (0 <=x<35):
    return "<35"
  if(35 <= x<=54):
      return "35 - 54"
  if (55 <= x <74):
        return "55 - 74"
  if (75 <= x <94):
        return "75 - 94"
  if (95 <= x <115):
        return "95 - 115"
  return ">=115"

# %%
df['ag']= df.apply(lambda tbl: custom_cs(tbl['peso']),
                      axis = 1)
df['ag']
# Out:
# 0         55 - 74
# 1         35 - 54
# 2           >=115
# 3             <35
# 4        95 - 115
#            ...
# 18635     75 - 94
# 18636     55 - 74
# 18637     35 - 54
# 18638     55 - 74
# 18639     75 - 94
# Name: ag, Length: 18640, dtype: object

# %%
ag = df.groupby(['peso']).size()
ag = ag.to_frame()
ag
# Out:
#          0
# peso
# 18.000   1
# 20.550   2
# 21.900   1
# 22.175   1
# 22.400   1
# ...     ..
# 161.450  1
# 165.000  1
# 167.900  1
# 168.600  1
# 170.600  1
#
# [2634 rows x 1 columns]

# %%
counts = df['ag'].value_counts()
counts
# Out:
# 55 - 74     7930
# 35 - 54     4406
# 75 - 94     3785
# >=115        974
# 95 - 115     775
# <35          770
# Name: ag, dtype: int64

# %%
counts = counts.to_frame()
counts
# Out:
#             ag
# 55 - 74   7930
# 35 - 54   4406
# 75 - 94   3785
# >=115      974
# 95 - 115   775
# <35        770

# %%
suma= counts.loc[:, 'ag'].sum()
suma
# Out:
# 18640

# %%
counts ['%'] = ((counts.loc[:, 'ag']/suma)*100).round(2)
counts
# Out:
#             ag      %
# 55 - 74   7930  42.54
# 35 - 54   4406  23.64
# 75 - 94   3785  20.31
# >=115      974   5.23
# 95 - 115   775   4.16
# <35        770   4.13

# %%
counts.index
# Out:
# Index(['55 - 74', '35 - 54', '75 - 94', '>=115', '95 - 115', '<35'], dtype='object')

# %%
counts= counts.reindex(['<35','35 - 54','55 - 74', '75 - 94','95 - 115', '>=115' ])
counts
# Out:
#             ag      %
# <35        770   4.13
# 35 - 54   4406  23.64
# 55 - 74   7930  42.54
# 75 - 94   3785  20.31
# 95 - 115   775   4.16
# >=115      974   5.23

# %%
counts['ag'].plot(kind = 'pie')

# %%
counts['ag'].plot(kind = 'pie',
                     figsize = (15,16),
                     autopct = '%1.1f%%',
                     pctdistance = 1.3,
                     labels = None,
                     startangle =90,
                     shadow = True,
                     )
plt.legend(labels = counts.index,
           bbox_to_anchor =(1.0,1.0)
           );

# %%
y= list(counts ['ag'])
x= list (counts.index)
plt.bar(x,y,
        width= 0.7,
        color = 'darkcyan');

# %%
agp = df.groupby(['ag','sexo']).size()
agp = agp.to_frame()
agp
# Out:
#                   0
# ag       sexo
# 35 - 54  1     1485
#          2     2921
# 55 - 74  1     3217
#          2     4713
# 75 - 94  1     2062
#          2     1723
# 95 - 115 1      478
#          2      297
# <35      1      439
#          2      331
# >=115    1      473
#          2      501

# %%
agp.index
# Out:
# MultiIndex([( '35 - 54', 1),
#             ( '35 - 54', 2),
#             ( '55 - 74', 1),
#             ( '55 - 74', 2),
#             ( '75 - 94', 1),
#             ( '75 - 94', 2),
#             ('95 - 115', 1),
#             ('95 - 115', 2),
#             (     '<35', 1),
#             (     '<35', 2),
#             (   '>=115', 1),
#             (   '>=115', 2)],
#            names=['ag', 'sexo'])

# %%
sns.catplot (x= 'ag',
             kind = 'count',
             data = df,
             hue= 'sexo',
             );

# %%
agp.loc[(slice(None), 1), :]
# Out:
#                   0
# ag       sexo
# 35 - 54  1     1485
# 55 - 74  1     3217
# 75 - 94  1     2062
# 95 - 115 1      478
# <35      1      439
# >=115    1      473

# %%
agp.loc[:, :]
# Out:
#                   0
# ag       sexo
# 35 - 54  1     1485
#          2     2921
# 55 - 74  1     3217
#          2     4713
# 75 - 94  1     2062
#          2     1723
# 95 - 115 1      478
#          2      297
# <35      1      439
#          2      331
# >=115    1      473
#          2      501

# %%
agp.index
# Out:
# MultiIndex([( '35 - 54', 1),
#             ( '35 - 54', 2),
#             ( '55 - 74', 1),
#             ( '55 - 74', 2),
#             ( '75 - 94', 1),
#             ( '75 - 94', 2),
#             ('95 - 115', 1),
#             ('95 - 115', 2),
#             (     '<35', 1),
#             (     '<35', 2),
#             (   '>=115', 1),
#             (   '>=115', 2)],
#            names=['ag', 'sexo'])

# %%
sns.catplot (x= 'ag',
             kind = 'count',
             data = df,
             hue= 'sexo',
             );

# %%
ag2 = df.groupby(['ag','sexo']).size()
ag2 = ag2.to_frame()
ag2
# Out:
#                   0
# ag       sexo
# 35 - 54  1     1485
#          2     2921
# 55 - 74  1     3217
#          2     4713
# 75 - 94  1     2062
#          2     1723
# 95 - 115 1      478
#          2      297
# <35      1      439
#          2      331
# >=115    1      473
#          2      501

# %%
df['peso'].min()
# Out:
# 18.0

# %%
df['peso'].max()
# Out:
# 170.6

# %%
sns.boxplot(data=df.loc[:,
                        ['peso', 'talla', 'cintura']
                        ]);
